# %%
#Our Imports.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing out of dataframe.
df = pd.read_csv('AsteroidDataset\\Asteroid_Updated.csv', low_memory=False)
asteroid_data = df

# %%
asteroid_data.name.unique
# Out:
# <bound method Series.unique of 0           Ceres
# 1          Pallas
# 2            Juno
# 3           Vesta
# 4         Astraea
#            ...
# 839709        NaN
# 839710        NaN
# 839711        NaN
# 839712        NaN
# 839713        NaN
# Name: name, Length: 839714, dtype: object>

# %%
asteroid_data.tail()
# Out:
#        name         a         e          i          om           w         q  \
# 839709  NaN  2.812945  0.664688   4.695700  183.310012  234.618352  0.943214
# 839710  NaN  2.645238  0.259376  12.574937    1.620020  339.568072  1.959126
# 839711  NaN  2.373137  0.202053   0.732484  176.499082  198.026527  1.893638
# 839712  NaN  2.260404  0.258348   9.661947  204.512448  148.496988  1.676433
# 839713  NaN  2.546442  0.287672   5.356238   70.709555  273.483265  1.813901
#
#               ad     per_y  data_arc  ...  UB  IR  spec_B spec_T   G  \
# 839709  4.682676  4.717914   17298.0  ... NaN NaN     NaN    NaN NaN
# 839710  3.331350  4.302346      16.0  ... NaN NaN     NaN    NaN NaN
# 839711  2.852636  3.655884       5.0  ... NaN NaN     NaN    NaN NaN
# 839712  2.844376  3.398501      10.0  ... NaN NaN     NaN    NaN NaN
# 839713  3.278983  4.063580      11.0  ... NaN NaN     NaN    NaN NaN
#
#             moid class         n          per          ma
# ...

# %%
asteroid_data.dtypes
# Out:
# name               object
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used          int64
# H                 float64
# neo                object
# pha                object
# diameter           object
# extent             object
# albedo            float64
# rot_per           float64
# GM                float64
# BV                float64
# UB                float64
# IR                float64
# spec_B             object
# spec_T             object
# G                 float64
# moid              float64
# class              object
# n                 float64
# per               float64
# ma                float64
# dtype: object

# %%
import seaborn as sns

sns.set()

# %%
asteroid_data_sorted_diameter = df.sort_values(by='diameter')

# %%
fig, axs = plt.subplots(nrows=1,
                        ncols=1,
                        figsize=(14,10))


sns.scatterplot(data=asteroid_data[0:20],
                x="diameter", #diameter of asteroid
                y="per", #per is Orbital period
                hue="name", #Name of the ateroid
                #palette "vLog",    
                ax=axs)
# Out:
# <Axes: xlabel='diameter', ylabel='per'>

# %%
asteroid_data[0:20].sort_values(by='pha')
# Out:
#           name         a         e          i          om           w  \
# 0        Ceres  2.769165  0.076009  10.594067   80.305532   73.597694
# 17   Melpomene  2.296654  0.217674  10.128731  150.383862  227.950847
# 16      Thetis  2.470354  0.133032   5.591205  125.552945  136.208250
# 15      Psyche  2.923814  0.133568   3.096005  150.045666  228.823071
# 14     Eunomia  2.644100  0.186084  11.752430  292.934339   98.498681
# 13       Irene  2.585567  0.166582   9.121646   86.122665   97.858985
# 12      Egeria  2.575981  0.085121  16.536125   43.221913   80.544823
# 11    Victoria  2.334315  0.220172   8.373074  235.410169   69.641819
# 10  Parthenope  2.453109  0.100472   4.629886  125.546585  195.550396
# 9       Hygiea  3.141539  0.112461   3.831560  283.202167  312.315206
# 8        Metis  2.385637  0.123114   5.576816   68.908577    6.417369
# 7        Flora  2.201764  0.156499   5.886955  110.889330  285.287462
# ...
